# %% [markdown]
# # Get the data + clean it

# %%
import pandas as pd
from statistics import mean
import numpy as np

# %%
df_union = pd.read_csv('dataset_3_labels_merged.csv', sep=';')
df_union.drop(columns=['commit number', 'committer name',
       'message', 'URL', 'author name'], inplace=True)
df_union
# Out:
#                                               commit ID  \
# 0     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 1     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 2     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 3     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 4     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# ...                                                 ...
# 2229  MDY6Q29tbWl0MjMyNTI5ODo3OWJlZmQwYzA4YzQ3NjZmOG...
# 2230  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2231  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2232  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2233  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                    message_preprocessed Decision Rationale  \
# 0     mm: reduce noise in show_mem for lowmem alloca...      yes       yes
# 1     While discussing early DMA pool pre-allocation...       no       yes
# ...

# %%
df_raters =  pd.read_csv('dataset_4_labels_anaonymous.csv', sep=';')
df_raters.drop(columns=['commit number', 'committer name',
       'message', 'URL', 'Inapplicable R1', 'Inapplicable R2', 'Inapplicable R3', 'author name'], inplace=True)
df_raters
# Out:
#                                               commit ID  \
# 0     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 1     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 2     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 3     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 4     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# ...                                                 ...
# 2328  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2329  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2330  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2331  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2332  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                    message_preprocessed Decision R1  \
# 0     mm: reduce noise in show_mem for lowmem alloca...         yes
# 1     While discussing early DMA pool pre-allocation...          no
# 2      Those zones are usually not\npopulated on all...          no
# ...

# %%
df_merged = pd.merge(df_raters, df_union, how='right', on =['commit ID','message_preprocessed'])
df_merged # more rows than expected
# Out:
#                                               commit ID  \
# 0     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 1     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 2     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 3     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 4     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# ...                                                 ...
# 2239  MDY6Q29tbWl0MjMyNTI5ODo3OWJlZmQwYzA4YzQ3NjZmOG...
# 2240  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2241  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2242  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2243  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                    message_preprocessed Decision R1  \
# 0     mm: reduce noise in show_mem for lowmem alloca...         yes
# 1     While discussing early DMA pool pre-allocation...          no
# 2      Those zones are usually not\npopulated on all...          no
# ...

# %%
2244  - 2234
# Out:
# 10

# %%
df_merged = pd.merge(df_raters, df_union, how='right', on =['commit ID','message_preprocessed'] , validate = 'm:1')
df_merged
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-26-710c8abbfe0e> in <cell line: 1>()
# ----> 1 df_merged = pd.merge(df_raters, df_union, how='right', on =['commit ID','message_preprocessed'] , validate = 'm:1')
#       2 df_merged
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     711         # are in fact unique.
#     712         if validate is not None:
# ...

# %%
df_union[df_union.duplicated(['message_preprocessed','commit ID'], keep=False)]  #  Keep= Flase,  all duplicates,
# Out:
#                                               commit ID  \
# 156   MDY6Q29tbWl0MjMyNTI5ODo5YzI3NmNjNjVhNThmYWY5OG...
# 163   MDY6Q29tbWl0MjMyNTI5ODo5YzI3NmNjNjVhNThmYWY5OG...
# 167   MDY6Q29tbWl0MjMyNTI5ODo5YzI3NmNjNjVhNThmYWY5OG...
# 1303  MDY6Q29tbWl0MjMyNTI5ODphNWJlMmQwZDFhODc0NmU3Ym...
# 1306  MDY6Q29tbWl0MjMyNTI5ODphNWJlMmQwZDFhODc0NmU3Ym...
# 1971  MDY6Q29tbWl0MjMyNTI5ODo0ZTk1MGY2ZjAxODlmNjVmOG...
# 1972  MDY6Q29tbWl0MjMyNTI5ODo0ZTk1MGY2ZjAxODlmNjVmOG...
#
#        message_preprocessed Decision Rationale Supporting Facts
# 156                  #NAME?       no        no              yes
# 163                  #NAME?       no       yes              yes
# 167                  #NAME?      yes       yes               no
# 1303                 #NAME?       no        no              yes
# 1306                 #NAME?      yes        no               no
# 1971  Remove fs.h from mm.h      yes        no               no
# 1972  Remove fs.h from mm.h      yes        no               no

# %%
df_raters[df_raters.duplicated(['message_preprocessed','commit ID'], keep=False)]
# Out:
#                                               commit ID  \
# 183   MDY6Q29tbWl0MjMyNTI5ODo5YzI3NmNjNjVhNThmYWY5OG...
# 190   MDY6Q29tbWl0MjMyNTI5ODo5YzI3NmNjNjVhNThmYWY5OG...
# 195   MDY6Q29tbWl0MjMyNTI5ODo5YzI3NmNjNjVhNThmYWY5OG...
# 1378  MDY6Q29tbWl0MjMyNTI5ODphNWJlMmQwZDFhODc0NmU3Ym...
# 1381  MDY6Q29tbWl0MjMyNTI5ODphNWJlMmQwZDFhODc0NmU3Ym...
# 2068  MDY6Q29tbWl0MjMyNTI5ODo0ZTk1MGY2ZjAxODlmNjVmOG...
# 2069  MDY6Q29tbWl0MjMyNTI5ODo0ZTk1MGY2ZjAxODlmNjVmOG...
#
#        message_preprocessed Decision R1 Decision R2 Decision R3 Rationale R1  \
# 183                  #NAME?          no          no          no           no
# 190                  #NAME?          no          no          no           no
# 195                  #NAME?          no         yes          no           no
# 1378                 #NAME?          no          no          no           no
# 1381                 #NAME?         yes         yes         yes           no
# ...

# %%
df_union.drop_duplicates(subset=['message_preprocessed','commit ID'], keep=False, inplace=True)  #  Keep= Flase,  removes all duplicates,
df_union
# Out:
#                                               commit ID  \
# 0     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 1     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 2     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 3     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 4     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# ...                                                 ...
# 2229  MDY6Q29tbWl0MjMyNTI5ODo3OWJlZmQwYzA4YzQ3NjZmOG...
# 2230  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2231  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2232  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2233  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                    message_preprocessed Decision Rationale  \
# 0     mm: reduce noise in show_mem for lowmem alloca...      yes       yes
# 1     While discussing early DMA pool pre-allocation...       no       yes
# ...

# %%
df_union[df_union.duplicated(['message_preprocessed','commit ID'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [commit ID, message_preprocessed, Decision, Rationale, Supporting Facts]
# Index: []

# %%
df_raters.drop_duplicates(subset=['message_preprocessed','commit ID'], keep=False, inplace=True)
df_raters
# Out:
#                                               commit ID  \
# 0     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 1     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 2     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 3     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 4     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# ...                                                 ...
# 2328  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2329  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2330  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2331  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2332  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                    message_preprocessed Decision R1  \
# 0     mm: reduce noise in show_mem for lowmem alloca...         yes
# 1     While discussing early DMA pool pre-allocation...          no
# 2      Those zones are usually not\npopulated on all...          no
# ...

# %%
df_raters[df_raters.duplicated(['message_preprocessed','commit ID'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [commit ID, message_preprocessed, Decision R1, Decision R2, Decision R3, Rationale R1, Rationale R2, Rationale R3, Supporting Facts R1, Supporting Facts R2, Supporting Facts R3]
# Index: []

# %%
df_merged = pd.merge(df_raters, df_union, how='right', on =['commit ID','message_preprocessed'] , validate = 'm:1')
df_merged
# Out:
#                                               commit ID  \
# 0     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 1     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 2     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 3     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 4     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# ...                                                 ...
# 2222  MDY6Q29tbWl0MjMyNTI5ODo3OWJlZmQwYzA4YzQ3NjZmOG...
# 2223  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2224  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2225  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2226  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                    message_preprocessed Decision R1  \
# 0     mm: reduce noise in show_mem for lowmem alloca...         yes
# 1     While discussing early DMA pool pre-allocation...          no
# 2      Those zones are usually not\npopulated on all...          no
# ...

# %% [markdown]
# ## duplicates on message_preprocessed only

# %%
df_merged[df_merged.duplicated(['message_preprocessed'], keep=False)] # I kept these, same sentences in different commits so could be in different contexts
# Out:
#                                               commit ID  \
# 112   MDY6Q29tbWl0MjMyNTI5ODphNzJhZmQ4NzMwODljNjk3MD...
# 115   MDY6Q29tbWl0MjMyNTI5ODphZThlYmE4YjVkNzIzYTRjYT...
# 807   MDY6Q29tbWl0MjMyNTI5ODphYWM0NTM2MzU1NDk2OTljMT...
# 907   MDY6Q29tbWl0MjMyNTI5ODo1NGU5ZTI5MTMyZDdjYWVmY2...
# 911   MDY6Q29tbWl0MjMyNTI5ODo2ZTBmYzQ2ZGMyMTUyZDNlMm...
# 1019  MDY6Q29tbWl0MjMyNTI5ODo0OTU1MGI2MDU1ODc5MjRiMz...
# 1445  MDY6Q29tbWl0MjMyNTI5ODpiNTI3MjNjNTYwN2Y3Njg0Yz...
# 1512  MDY6Q29tbWl0MjMyNTI5ODoyNmViYzk4NDkxM2I2YThkOD...
# 1526  MDY6Q29tbWl0MjMyNTI5ODo3YzU5YWVjODMwYzdlZDZjNz...
# 1653  MDY6Q29tbWl0MjMyNTI5ODo4Njc1NzhjYmNjYjA4OTNjYz...
# 1665  MDY6Q29tbWl0MjMyNTI5ODpkYWFmMWU2ODg3NGMwNzhhMT...
# 1676  MDY6Q29tbWl0MjMyNTI5ODo1YTJkNDE5NjFkZDY4MTViOD...
# 1888  MDY6Q29tbWl0MjMyNTI5ODpjN2JhNWM5ZTgxNzY3MDRiZm...
#
#                                    message_preprocessed Decision R1  \
# 112   Remove the unused arguments and update all cal...         yes
# ...

# %%
df_merged
# Out:
#                                               commit ID  \
# 0     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 1     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 2     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 3     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 4     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# ...                                                 ...
# 2222  MDY6Q29tbWl0MjMyNTI5ODo3OWJlZmQwYzA4YzQ3NjZmOG...
# 2223  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2224  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2225  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2226  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                    message_preprocessed Decision R1  \
# 0     mm: reduce noise in show_mem for lowmem alloca...         yes
# 1     While discussing early DMA pool pre-allocation...          no
# 2      Those zones are usually not\npopulated on all...          no
# ...

# %%
df_merged['Decision R1']=df_merged['Decision R1'].apply(lambda x: 1 if x=='yes' else 0)
df_merged['Decision R2']=df_merged['Decision R2'].apply(lambda x: 1 if x=='yes' else 0)
df_merged['Decision R3']=df_merged['Decision R3'].apply(lambda x: 1 if x=='yes' else 0)
df_merged['Decision']=df_merged['Decision'].apply(lambda x: 1 if x=='yes' else 0)


df_merged['Rationale R1']=df_merged['Rationale R1'].apply(lambda x: 1 if x=='yes' else 0)
df_merged['Rationale R2']=df_merged['Rationale R2'].apply(lambda x: 1 if x=='yes' else 0)
df_merged['Rationale R3']=df_merged['Rationale R3'].apply(lambda x: 1 if x=='yes' else 0)
df_merged['Rationale']=df_merged['Rationale'].apply(lambda x: 1 if x=='yes' else 0)


df_merged['Supporting Facts R1']=df_merged['Supporting Facts R1'].apply(lambda x: 1 if x=='yes' else 0)
df_merged['Supporting Facts R2']=df_merged['Supporting Facts R2'].apply(lambda x: 1 if x=='yes' else 0)
df_merged['Supporting Facts R3']=df_merged['Supporting Facts R3'].apply(lambda x: 1 if x=='yes' else 0)
df_merged['Supporting Facts']=df_merged['Supporting Facts'].apply(lambda x: 1 if x=='yes' else 0)

df_merged
# Out:
#                                               commit ID  \
# 0     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 1     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 2     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 3     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 4     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# ...                                                 ...
# 2222  MDY6Q29tbWl0MjMyNTI5ODo3OWJlZmQwYzA4YzQ3NjZmOG...
# 2223  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2224  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2225  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2226  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                    message_preprocessed  Decision R1  \
# 0     mm: reduce noise in show_mem for lowmem alloca...            1
# 1     While discussing early DMA pool pre-allocation...            0
# 2      Those zones are usually not\npopulated on all...            0
# ...

# %%
df_merged.to_csv('dataset_merged_raters.csv',sep=';', index=False) # TODO: keep this file somewhere, In case I need it to train calssifier per rater later

# %% [markdown]
# # Raters performance

# %%
import pandas as pd
df_merged = pd.read_csv('dataset_merged_raters.csv',sep=';')
df_merged
# Out:
#                                               commit ID  \
# 0     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 1     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 2     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 3     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# 4     C_kwDOACN7MtoAKDk3NGY0MzY3ZGQzMTVhY2MxNWFkNGE2...
# ...                                                 ...
# 2222  MDY6Q29tbWl0MjMyNTI5ODo3OWJlZmQwYzA4YzQ3NjZmOG...
# 2223  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2224  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2225  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 2226  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                    message_preprocessed  Decision R1  \
# 0     mm: reduce noise in show_mem for lowmem alloca...            1
# 1     While discussing early DMA pool pre-allocation...            0
# 2      Those zones are usually not\npopulated on all...            0
# ...

# %%
df_merged.columns
# Out:
# Index(['commit ID', 'message_preprocessed', 'Decision R1', 'Decision R2',
#        'Decision R3', 'Rationale R1', 'Rationale R2', 'Rationale R3',
#        'Supporting Facts R1', 'Supporting Facts R2', 'Supporting Facts R3',
#        'Decision', 'Rationale', 'Supporting Facts'],
#       dtype='object')

# %%
for col in ['Decision R1', 'Decision R2', 'Decision R3', 'Rationale R1', 'Rationale R2', 'Rationale R3',
       'Supporting Facts R1', 'Supporting Facts R2', 'Supporting Facts R3',   'Decision', 'Rationale', 'Supporting Facts']:
  value_counts = df_merged[col].value_counts().to_dict()
  print(col)
  print(value_counts)
# Out:
# Decision R1
# {1: 1215, 0: 1012}
# Decision R2
# {1: 1222, 0: 1005}
# Decision R3
# {0: 1254, 1: 973}
# Rationale R1
# {0: 1364, 1: 863}
# Rationale R2
# {0: 1292, 1: 935}
# Rationale R3
# {0: 1277, 1: 950}
# Supporting Facts R1
# {0: 1496, 1: 731}
# Supporting Facts R2
# {0: 1335, 1: 892}
# Supporting Facts R3
# {0: 1168, 1: 1059}
# Decision
# {1: 1339, 0: 888}
# Rationale
# {1: 1250, 0: 977}
# Supporting Facts
# {1: 1177, 0: 1050}

# %%
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


for x in ['Decision', 'Rationale', 'Supporting Facts']:
  for r in '123':

    y_true = np.array(df_merged[x])
    y_pred = np.array(df_merged[x + ' R'+r])

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    print(f"R{r} {x} Accuracy: {accuracy}")
    print(f"R{r} {x} Precision: {precision}")
    print(f"R{r} {x} Recall: {recall}")
    print(f"R{r} {x} F1 Score: {f1}")
    print((tn, fp, fn, tp))

    print()
# Out:
# R1 Decision Accuracy: 0.9443197126178716
# R1 Decision Precision: 1.0
# R1 Decision Recall: 0.90739357729649
# R1 Decision F1 Score: 0.951448707909162
# (888, 0, 124, 1215)
#
# R2 Decision Accuracy: 0.9474629546475078
# R2 Decision Precision: 1.0
# R2 Decision Recall: 0.912621359223301
# R2 Decision F1 Score: 0.9543147208121827
# (888, 0, 117, 1222)
#
# R3 Decision Accuracy: 0.8356533453075887
# R3 Decision Precision: 1.0
# R3 Decision Recall: 0.7266616878267363
# R3 Decision F1 Score: 0.8416955017301038
# (888, 0, 366, 973)
#
# R1 Rationale Accuracy: 0.8262236192186798
# R1 Rationale Precision: 1.0
# R1 Rationale Recall: 0.6904
# R1 Rationale F1 Score: 0.816848083293895
# (977, 0, 387, 863)
#
# R2 Rationale Accuracy: 0.8585541086663673
# R2 Rationale Precision: 1.0
# R2 Rationale Recall: 0.748
# R2 Rationale F1 Score: 0.8558352402745996
# (977, 0, 315, 935)
#
# R3 Rationale Accuracy: 0.8652896273013022
# R3 Rationale Precision: 1.0
# R3 Rationale Recall: 0.76
# ...

# %% [markdown]
# Best raters: \\
# -For decision category :  R2 \\
# -For rationale category:  R3 \\
#
# -For Supporting Facts category: R3
