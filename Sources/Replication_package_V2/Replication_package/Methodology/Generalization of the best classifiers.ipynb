# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model

# %% [markdown]
# ## get the classfiers

# %%
### same preprocessing  as training
df = pd.read_csv('dataset_3_labels_merged.csv', sep=';')
texts = df['message_preprocessed']
dataf = pd.DataFrame({'text': texts})

max_words = 1000
tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(dataf['text'])
vocab_size = len(tokenizer.word_index) + 1

sequences = tokenizer.texts_to_sequences(dataf['text'])
max_sequence_length = max(len(seq) for seq in sequences)

########  get the classifiers
model_rationale = load_model('bi_lstm_model_rationale.h5')
model_decision = load_model('bi_lstm_model_decision.h5')

# %% [markdown]
# # Generalization to other mm modules (slob.c)

# %% [markdown]
# ## Test the classifiers

# %%
df_slob = pd.read_csv('data_file_slob_preprocessed.csv' )
df_slob
# Out:
#      Unnamed: 0                                          commit ID  \
# 0             0  C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 1             0  C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 2             0  C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 3             1  C_kwDOACN7MtoAKDA1YTk0MDY1NmUxZWIyMDI2ZDllZTMx...
# 4             1  C_kwDOACN7MtoAKDA1YTk0MDY1NmUxZWIyMDI2ZDllZTMx...
# ..          ...                                                ...
# 828         145  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 829         145  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 830         145  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 831         145  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 832         145  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
#
#          author name   committer name  \
# 0    Vlastimil Babka  Vlastimil Babka
# 1    Vlastimil Babka  Vlastimil Babka
# 2    Vlastimil Babka  Vlastimil Babka
# 3          Kees Cook  Vlastimil Babka
# 4          Kees Cook  Vlastimil Babka
# ..               ...              ...
# 828     Matt Mackall   Linus Torvalds
# 829     Matt Mackall   Linus Torvalds
# 830     Matt Mackall   Linus Torvalds
# 831     Matt Mackall   Linus Torvalds
# 832     Matt Mackall   Linus Torvalds
#
#                                                message  \
# 0    mm/slob: remove slob.c\n\nRemove the SLOB impl...
# 1    mm/slob: remove slob.c\n\nRemove the SLOB impl...
# 2    mm/slob: remove slob.c\n\nRemove the SLOB impl...
# 3    slab: Introduce kmalloc_size_roundup()\n\nIn t...
# 4    slab: Introduce kmalloc_size_roundup()\n\nIn t...
# ..                                                 ...
# 828  [PATCH] slob: introduce the SLOB allocator\n\n...
# 829  [PATCH] slob: introduce the SLOB allocator\n\n...
# 830  [PATCH] slob: introduce the SLOB allocator\n\n...
# 831  [PATCH] slob: introduce the SLOB allocator\n\n...
# 832  [PATCH] slob: introduce the SLOB allocator\n\n...
#
#                                                    URL  \
# 0    https://api.github.com/repos/torvalds/linux/gi...
# 1    https://api.github.com/repos/torvalds/linux/gi...
# 2    https://api.github.com/repos/torvalds/linux/gi...
# 3    https://api.github.com/repos/torvalds/linux/gi...
# 4    https://api.github.com/repos/torvalds/linux/gi...
# ..                                                 ...
# 828  https://api.github.com/repos/torvalds/linux/gi...
# 829  https://api.github.com/repos/torvalds/linux/gi...
# 830  https://api.github.com/repos/torvalds/linux/gi...
# 831  https://api.github.com/repos/torvalds/linux/gi...
# 832  https://api.github.com/repos/torvalds/linux/gi...
#
#                                   message_preprocessed
# 0                               mm/slob: remove slob.c
# 1                       Remove the SLOB implementation
# 2                     RIP SLOB allocator (2006 - 2023)
# 3               slab: Introduce kmalloc_size_roundup()
# 4    In the effort to help the compiler reason abou...
# ..                                                 ...
# 828  It's been tested extensively in the Linux-tiny...
# 829   I've also\nstress-tested it with make -j 8 co...
# 830  Here's a comparison for otherwise identical bu...
# 831  $ size vmlinux*\n   text    data     bss     d...
# 832                    SLAB          SLOB      delt...
#
# [833 rows x 7 columns]

# %%
X_test =  df_slob['message_preprocessed']

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(X_test.astype(str))
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)


# Making Decision predictions
y_pred_prob = model_decision.predict(padded_sequences) ## change here !!!!!
y_pred = (y_pred_prob > 0.5).astype(int)  # Threshold probabilities to get binary predictions
y_pred = y_pred.flatten()


df_slob_predicted = pd.DataFrame({'commit ID': df_slob['commit ID']  , 'text': X_test, 'predicted_decision':y_pred})
df_slob_predicted
# Out:
# 27/27 [==============================] - 1s 47ms/step
#                                              commit ID  \
# 0    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 1    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 2    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 3    C_kwDOACN7MtoAKDA1YTk0MDY1NmUxZWIyMDI2ZDllZTMx...
# 4    C_kwDOACN7MtoAKDA1YTk0MDY1NmUxZWIyMDI2ZDllZTMx...
# ..                                                 ...
# 828  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 829  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 830  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 831  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 832  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
#
#                                                   text  predicted_decision
# 0                               mm/slob: remove slob.c                   1
# 1                       Remove the SLOB implementation                   1
# 2                     RIP SLOB allocator (2006 - 2023)                   0
# 3               slab: Introduce kmalloc_size_roundup()                   1
# 4    In the effort to help the compiler reason abou...                   1
# ..                                                 ...                 ...
# 828  It's been tested extensively in the Linux-tiny...                   0
# 829   I've also\nstress-tested it with make -j 8 co...                   1
# 830  Here's a comparison for otherwise identical bu...                   1
# 831  $ size vmlinux*\n   text    data     bss     d...                   1
# 832                    SLAB          SLOB      delt...                   1
#
# [833 rows x 3 columns]

# %%
# Making Rationale predictions
y_pred_prob = model_rationale.predict(padded_sequences) ## change here !!!!!
y_pred = (y_pred_prob > 0.5).astype(int)  # Threshold probabilities to get binary predictions
y_pred = y_pred.flatten()


df_slob_predicted['predicted_rationale'] = y_pred
df_slob_predicted
# Out:
# 27/27 [==============================] - 1s 30ms/step
#                                              commit ID  \
# 0    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 1    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 2    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 3    C_kwDOACN7MtoAKDA1YTk0MDY1NmUxZWIyMDI2ZDllZTMx...
# 4    C_kwDOACN7MtoAKDA1YTk0MDY1NmUxZWIyMDI2ZDllZTMx...
# ..                                                 ...
# 828  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 829  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 830  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 831  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 832  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
#
#                                                   text  predicted_decision  \
# 0                               mm/slob: remove slob.c                   1
# 1                       Remove the SLOB implementation                   1
# 2                     RIP SLOB allocator (2006 - 2023)                   0
# 3               slab: Introduce kmalloc_size_roundup()                   1
# 4    In the effort to help the compiler reason abou...                   1
# ..                                                 ...                 ...
# 828  It's been tested extensively in the Linux-tiny...                   0
# 829   I've also\nstress-tested it with make -j 8 co...                   1
# 830  Here's a comparison for otherwise identical bu...                   1
# 831  $ size vmlinux*\n   text    data     bss     d...                   1
# 832                    SLAB          SLOB      delt...                   1
#
#      predicted_rationale
# 0                      1
# 1                      1
# 2                      0
# 3                      0
# 4                      1
# ..                   ...
# 828                    0
# 829                    0
# 830                    1
# 831                    1
# 832                    1
#
# [833 rows x 4 columns]

# %%
df_slob_predicted.to_csv('generalization_results_on_the_slob.csv', sep=';', index=False)

# %% [markdown]
# ## Choose commits for validation

# %%
import pandas as pd
df_slob_predicted = pd.read_csv('generalization_results_on_the_slob.csv' , sep=';', encoding ='latin-1')
df_slob_predicted
# Out:
#                                              commit ID  \
# 0    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 1    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 2    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 3    C_kwDOACN7MtoAKDA1YTk0MDY1NmUxZWIyMDI2ZDllZTMx...
# 4    C_kwDOACN7MtoAKDA1YTk0MDY1NmUxZWIyMDI2ZDllZTMx...
# ..                                                 ...
# 828  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 829  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 830  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 831  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
# 832  MDY6Q29tbWl0MjMyNTI5ODoxMGNlZjYwMjk1MDI5MTViZG...
#
#                                                   text  predicted_decision  \
# 0                               mm/slob: remove slob.c                   1
# 1                       Remove the SLOB implementation                   1
# 2                     RIP SLOB allocator (2006 - 2023)                   0
# 3               slab: Introduce kmalloc_size_roundup()                   1
# 4    In the effort to help the compiler reason abou...                   1
# ..                                                 ...                 ...
# 828  It's been tested extensively in the Linux-tiny...                   0
# 829   I've also\nstress-tested it with make -j 8 co...                   1
# 830  Here's a comparison for otherwise identical bu...                   1
# 831  $ size vmlinux*\n   text    data     bss     d...                   1
# 832                    SLAB          SLOB      delt...                   1
#
#      predicted_rationale
# 0                      1
# 1                      1
# 2                      0
# 3                      0
# 4                      1
# ..                   ...
# 828                    0
# 829                    0
# 830                    1
# 831                    1
# 832                    1
#
# [833 rows x 4 columns]

# %% [markdown]
# choose a sample of 20 commits for validation

# %%
unique_commits_IDs = df_slob_predicted['commit ID'].unique()
len(unique_commits_IDs)
# Out:
# 146

# %%
import random

random_commits_slob = random.choices(list(unique_commits_IDs), k=20)  # random 20 commits

random_commits_slob
# Out:
# ['C_kwDOACN7MtoAKGJkNTNjZTRkYTI1MmRkYjFhZTQyNTdjMTY0ZjgwYWVhM2Q4YWI5MGM',
#  'MDY6Q29tbWl0MjMyNTI5ODo3MDA5NmE1NjFkMWUwOTEyMGJhZTFmMjkzZjM2MzJjZWRiZmQ1YzY4',
#  'MDY6Q29tbWl0MjMyNTI5ODpmMWI2ZWI2ZTZiZTE0OWI0MGViYjAxM2Y1YmZlMmFjODZiNmYxYzFi',
#  'MDY6Q29tbWl0MjMyNTI5ODoyNDA4YzU1MDM3YzNmN2Q1MWE4YTEwMDAyNWM0NzU5NWU3MWI4Mzhj',
#  'MDY6Q29tbWl0MjMyNTI5ODozYjBlZmRmYTFlNzE5MzAzNTM2YzA0ZDlhYmNhNDNhYmViNDBmODBh',
#  'MDY6Q29tbWl0MjMyNTI5ODowMzljYTRlNzRhMWNmNjBiZDc0ODczMjRhNTY0ZWNmNWM5ODFmMjU0',
#  'MDY6Q29tbWl0MjMyNTI5ODo1ZTE4ZTJiOGIzZDQ1M2U2OGFjY2MzZTI5NTY0M2ZlNGI1YmJjMjk1',
#  'MDY6Q29tbWl0MjMyNTI5ODo1MWNjNTA2ODVhNDI3NWM2YTAyNjUzNjcwYWY5ZjEwOGE2NGUwMWNm',
#  'MDY6Q29tbWl0MjMyNTI5ODo0YmE5YjlkMGJhMGE0OWQ5MWZhNjQxN2M3NTEwZWUzNmY0OGNmOTU3',
#  'MDY6Q29tbWl0MjMyNTI5ODo4Y2Y5ODY0YjEzODI4NTFkOTBjN2M1MDVmODQ0MWM4OTI4ZjE0Njll',
#  'MDY6Q29tbWl0MjMyNTI5ODo4NWJhOTRiYTA1OTIyOTYwNTNmN2YyODQ2ODEyMTczNDI0YWZlMWNi',
#  'MDY6Q29tbWl0MjMyNTI5ODo1YmIxYmIzNTNjZmUzNDNmYzNjODRmYWYwNmY3MmJhMzA5ZmRlNTQx',
#  'C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJkYmFjN2JlODQ0YmFkMTkzZmU',
#  'MDY6Q29tbWl0MjMyNTI5ODo0NTkwNjg1NTQ2YTM3NGZiMGY2MDY4MmNlMGUzYTZmZDQ4OTExZDQ2',
#  'MDY6Q29tbWl0MjMyNTI5ODo2NzkyOTliMzJkYmY5YmFjNGJkYWVkYzg1MGZiOTVkMGY4MWI0OTYz',
#  'MDY6Q29tbWl0MjMyNTI5ODo3ZWQ5ZjdlNWRiNThjNmU4YzJiNGI3MzhhNzVkNWRjZDhlMTdhYWQ1',
#  'MDY6Q29tbWl0MjMyNTI5ODpkNjAyZGFiYWViYTc5ZGY5MGNjNjdjMzJkNWZlNGVlMGQ1ZTJiNzNh',
#  'MDY6Q29tbWl0MjMyNTI5ODo2MDA2MzQ5N2E5NWU3MTZjOWE2ODlhZjNiZTI2ODdkMjYxZjExNWI0',
#  'MDY6Q29tbWl0MjMyNTI5ODphNTBiODU0ZTA3M2NkMzMzNWJiYmFkYThkY2ZmODNhODU3Mjk3ZGQ3',
#  'MDY6Q29tbWl0MjMyNTI5ODo0ODQ3NDhmMGI2NWExOTUwYjJiOTNmNDQ0YTIyODdlOGRkMmNlZGQ2']

# %%
df_slob_predicted_sample = df_slob_predicted.loc[df_slob_predicted['commit ID'].isin(random_commits_slob)]
df_slob_predicted_sample
# Out:
#                                              commit ID  \
# 0    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 1    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 2    C_kwDOACN7MtoAKDY2MzBlOTUwZDUzMmZmYWJjZTNhNGJk...
# 67   C_kwDOACN7MtoAKGJkNTNjZTRkYTI1MmRkYjFhZTQyNTdj...
# 68   C_kwDOACN7MtoAKGJkNTNjZTRkYTI1MmRkYjFhZTQyNTdj...
# ..                                                 ...
# 652  MDY6Q29tbWl0MjMyNTI5ODo0YmE5YjlkMGJhMGE0OWQ5MW...
# 653  MDY6Q29tbWl0MjMyNTI5ODo0YmE5YjlkMGJhMGE0OWQ5MW...
# 660  MDY6Q29tbWl0MjMyNTI5ODoyNDA4YzU1MDM3YzNmN2Q1MW...
# 661  MDY6Q29tbWl0MjMyNTI5ODoyNDA4YzU1MDM3YzNmN2Q1MW...
# 662  MDY6Q29tbWl0MjMyNTI5ODoyNDA4YzU1MDM3YzNmN2Q1MW...
#
#                                                   text  predicted_decision  \
# 0                               mm/slob: remove slob.c                   1
# 1                       Remove the SLOB implementation                   1
# 2                     RIP SLOB allocator (2006 - 2023)                   0
# 67                mm/slob: make kmem_cache_boot static                   0
# 68    kmem_cache_boot is never accessed outside slob.c                   0
# ..                                                 ...                 ...
# 652   The object\npointer is placed before the kmem...                   0
# 653  Convert\n        ctor(void *object, struct kme...                   0
# 660  {slub, slob}: use unlikely() for kfree(ZERO_OR...                   0
# 661  Considering kfree(NULL) would normally occur o...                   1
# 662                             SLAB has this already.                   0
#
#      predicted_rationale
# 0                      1
# 1                      1
# 2                      0
# 67                     0
# 68                     0
# ..                   ...
# 652                    0
# 653                    0
# 660                    0
# 661                    1
# 662                    1
#
# [91 rows x 4 columns]

# %%
set(df_slob_predicted_sample['commit ID'].unique()) == set(random_commits_slob)
# Out:
# True

# %%
df_slob_predicted_sample.to_csv('sample_of_generalization_results_on_the_slob.csv', sep=';', index=False)

# %% [markdown]
# ## Alignement of Raters (post-validation)

# %%
import pandas as pd

# %%
df_b = pd.read_csv('Rater_1_sample_of_generalization_results_on_the_slob.csv' )
df_b = df_b.rename(columns={"Agree decision ? ": "Agree decision R1", "Agree rationale ? ": "Agree rationale R1"})

df_mi = pd.read_csv('Rater_2_sample_of_generalization_results_on_the_slob.csv' )
df_mi = df_mi.rename(columns={"Agree decision ? ": "Agree decision R2", "Agree rationale ? ": "Agree rationale R2"})

df_mo = pd.read_csv('Rater_3_sample_of_generalization_results_on_the_slob.csv' )
df_mo = df_mo.rename(columns={"Agree decision ? ": "Agree decision R3", "Agree rationale ? ": "Agree rationale R3"})

# %%
df_slob_validation = df_b
df_slob_validation['Agree decision R2'] = df_mi['Agree decision R2']
df_slob_validation['Agree rationale R2'] = df_mi['Agree rationale R2']
df_slob_validation['Agree decision R3'] = df_mo['Agree decision R3']
df_slob_validation['Agree rationale R3'] = df_mo['Agree rationale R3']
df_slob_validation

# %%
len(df_slob_validation[(df_slob_validation['Agree decision R1'] == "yes") & (df_slob_validation['Agree decision R2']=="yes") & (df_slob_validation['Agree decision R3'] == "yes")  ])
# Out:
# 56

# %%
len( df_slob_validation[(df_slob_validation['Agree rationale R1'] == "yes") & (df_slob_validation['Agree rationale R2']=="yes") & (df_slob_validation['Agree rationale R3'] == "yes")  ] )
# Out:
# 51

# %%
# yes and no, agreement
len(df_slob_validation[(df_slob_validation['Agree decision R1'] == df_slob_validation['Agree decision R2'] ) & (df_slob_validation['Agree decision R3'] == df_slob_validation['Agree decision R2'] )  ])
# Out:
# 72

# %%
# yes and no, agreement
len( df_slob_validation[(df_slob_validation['Agree rationale R1'] == df_slob_validation['Agree rationale R2'] )  & (df_slob_validation['Agree rationale R3'] == df_slob_validation['Agree rationale R2'] )  ] )
# Out:
# 60

# %% [markdown]
# # Generalization to other components (drivers/acpi sub-project )

# %% [markdown]
# ## Test the classifiers

# %%
df_button = pd.read_csv('data_file_button_preprocessed.csv' )
df_button
# Out:
#      Unnamed: 0                                          commit ID  \
# 0             0  C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 1             0  C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 2             0  C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 3             0  C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 4             1  C_kwDOACN7MtoAKGU0ZTYyZDVmZDhlY2IwZWE0MTc0YWZk...
# ..          ...                                                ...
# 571         109  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 572         109  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 573         109  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 574         109  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 575         109  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#            author name     committer name  \
# 0              Ken Xue  Rafael J. Wysocki
# 1              Ken Xue  Rafael J. Wysocki
# 2              Ken Xue  Rafael J. Wysocki
# 3              Ken Xue  Rafael J. Wysocki
# 4    Rafael J. Wysocki  Rafael J. Wysocki
# ..                 ...                ...
# 571     Linus Torvalds     Linus Torvalds
# 572     Linus Torvalds     Linus Torvalds
# 573     Linus Torvalds     Linus Torvalds
# 574     Linus Torvalds     Linus Torvalds
# 575     Linus Torvalds     Linus Torvalds
#
#                                                message  \
# 0    ACPI: button: trigger wakeup key events\n\nAnd...
# 1    ACPI: button: trigger wakeup key events\n\nAnd...
# 2    ACPI: button: trigger wakeup key events\n\nAnd...
# 3    ACPI: button: trigger wakeup key events\n\nAnd...
# 4    ACPI: button: Use different notify handlers fo...
# ..                                                 ...
# 571  Linux-2.6.12-rc2\n\nInitial git repository bui...
# 572  Linux-2.6.12-rc2\n\nInitial git repository bui...
# 573  Linux-2.6.12-rc2\n\nInitial git repository bui...
# 574  Linux-2.6.12-rc2\n\nInitial git repository bui...
# 575  Linux-2.6.12-rc2\n\nInitial git repository bui...
#
#                                                    URL  \
# 0    https://api.github.com/repos/torvalds/linux/gi...
# 1    https://api.github.com/repos/torvalds/linux/gi...
# 2    https://api.github.com/repos/torvalds/linux/gi...
# 3    https://api.github.com/repos/torvalds/linux/gi...
# 4    https://api.github.com/repos/torvalds/linux/gi...
# ..                                                 ...
# 571  https://api.github.com/repos/torvalds/linux/gi...
# 572  https://api.github.com/repos/torvalds/linux/gi...
# 573  https://api.github.com/repos/torvalds/linux/gi...
# 574  https://api.github.com/repos/torvalds/linux/gi...
# 575  https://api.github.com/repos/torvalds/linux/gi...
#
#                                   message_preprocessed
# 0              ACPI: button: trigger wakeup key events
# 1    Andorid can wakeup from various wakeup sources...
# 2    Regarding pressing acpi power button, it can r...
# 3    So, send wakeup key event to user space during...
# 4    ACPI: button: Use different notify handlers fo...
# ..                                                 ...
# 571                                   Linux-2.6.12-rc2
# 572                       Initial git repository build
# 573  I'm not bothering with the full history,\neven...
# 574  We can create a separate "historical" git\narc...
# 575                                        Let it rip!
#
# [576 rows x 7 columns]

# %%
X_test =  df_button['message_preprocessed']

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(X_test.astype(str))
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)


# Making Decision predictions
y_pred_prob = model_decision.predict(padded_sequences) ## change here !!!!!
y_pred = (y_pred_prob > 0.5).astype(int)  # Threshold probabilities to get binary predictions
y_pred = y_pred.flatten()


df_button_predicted = pd.DataFrame({'commit ID': df_button['commit ID'] , 'text': X_test, 'predicted_decision':y_pred})
df_button_predicted
# Out:
# 18/18 [==============================] - 1s 31ms/step
#                                              commit ID  \
# 0    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 1    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 2    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 3    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 4    C_kwDOACN7MtoAKGU0ZTYyZDVmZDhlY2IwZWE0MTc0YWZk...
# ..                                                 ...
# 571  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 572  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 573  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 574  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 575  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                                   text  predicted_decision
# 0              ACPI: button: trigger wakeup key events                   1
# 1    Andorid can wakeup from various wakeup sources...                   0
# 2    Regarding pressing acpi power button, it can r...                   0
# 3    So, send wakeup key event to user space during...                   1
# 4    ACPI: button: Use different notify handlers fo...                   1
# ..                                                 ...                 ...
# 571                                   Linux-2.6.12-rc2                   1
# 572                       Initial git repository build                   1
# 573  I'm not bothering with the full history,\neven...                   1
# 574  We can create a separate "historical" git\narc...                   1
# 575                                        Let it rip!                   1
#
# [576 rows x 3 columns]

# %%
# Making Rationale predictions
y_pred_prob = model_rationale.predict(padded_sequences) ## change here !!!!!
y_pred = (y_pred_prob > 0.5).astype(int)  # Threshold probabilities to get binary predictions
y_pred = y_pred.flatten()


df_button_predicted['predicted_rationale'] = y_pred
df_button_predicted
# Out:
# 18/18 [==============================] - 1s 32ms/step
#                                              commit ID  \
# 0    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 1    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 2    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 3    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 4    C_kwDOACN7MtoAKGU0ZTYyZDVmZDhlY2IwZWE0MTc0YWZk...
# ..                                                 ...
# 571  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 572  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 573  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 574  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 575  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                                   text  predicted_decision  \
# 0              ACPI: button: trigger wakeup key events                   1
# 1    Andorid can wakeup from various wakeup sources...                   0
# 2    Regarding pressing acpi power button, it can r...                   0
# 3    So, send wakeup key event to user space during...                   1
# 4    ACPI: button: Use different notify handlers fo...                   1
# ..                                                 ...                 ...
# 571                                   Linux-2.6.12-rc2                   1
# 572                       Initial git repository build                   1
# 573  I'm not bothering with the full history,\neven...                   1
# 574  We can create a separate "historical" git\narc...                   1
# 575                                        Let it rip!                   1
#
#      predicted_rationale
# 0                      1
# 1                      1
# 2                      0
# 3                      0
# 4                      1
# ..                   ...
# 571                    1
# 572                    1
# 573                    0
# 574                    1
# 575                    0
#
# [576 rows x 4 columns]

# %%
df_button_predicted.to_csv('generalization_results_on_the_button.csv', sep=';', index=False)

# %% [markdown]
# ## Choose 20 commits for validation

# %%
import pandas as pd
df_button_predicted = pd.read_csv('generalization_results_on_the_button.csv' , sep=';', encoding ='latin-1')
df_button_predicted
# Out:
#                                              commit ID  \
# 0    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 1    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 2    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 3    C_kwDOACN7MtoAKDE2ZjcwZmVhYWJlOWZkZTBhZjcwM2Yy...
# 4    C_kwDOACN7MtoAKGU0ZTYyZDVmZDhlY2IwZWE0MTc0YWZk...
# ..                                                 ...
# 571  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 572  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 573  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 574  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
# 575  MDY6Q29tbWl0MjMyNTI5ODoxZGExNzdlNGMzZjQxNTI0ZT...
#
#                                                   text  predicted_decision  \
# 0              ACPI: button: trigger wakeup key events                   1
# 1    Andorid can wakeup from various wakeup sources...                   0
# 2    Regarding pressing acpi power button, it can r...                   0
# 3    So, send wakeup key event to user space during...                   1
# 4    ACPI: button: Use different notify handlers fo...                   1
# ..                                                 ...                 ...
# 571                                   Linux-2.6.12-rc2                   1
# 572                       Initial git repository build                   1
# 573  I'm not bothering with the full history,\neven...                   1
# 574  We can create a separate "historical" git\narc...                   1
# 575                                        Let it rip!                   1
#
#      predicted_rationale
# 0                      1
# 1                      1
# 2                      0
# 3                      0
# 4                      1
# ..                   ...
# 571                    1
# 572                    1
# 573                    0
# 574                    1
# 575                    0
#
# [576 rows x 4 columns]

# %%
unique_commits_IDs_button = df_button_predicted['commit ID'].unique()
len(unique_commits_IDs_button)
# Out:
# 110

# %%
import random

random_commits_button = random.choices(list(unique_commits_IDs_button), k=20)  # random 20 commits

random_commits_button
# Out:
# ['MDY6Q29tbWl0MjMyNTI5ODoyMTk4OGE4ZTUxNDc5Y2VmZmU3YjA1NjhiMTcwZWZmYWJiNzA4ZGZl',
#  'MDY6Q29tbWl0MjMyNTI5ODphYzFjYzZiNDg1NmZmYTdlY2I4MThiM2NlYjgyYmZjNDM1OTdkNjEz',
#  'MDY6Q29tbWl0MjMyNTI5ODoxM2MxOTljMGQwY2Y3OGIyNzU5Mjk5MTEyOWZiOGNiY2ZjNTE2NGRl',
#  'MDY6Q29tbWl0MjMyNTI5ODo0YmU0NGZjZDNiZjY0OGI3ODJmNDQ2MGZkMDZkZmFlNmM0MmRlZDRi',
#  'MDY6Q29tbWl0MjMyNTI5ODoyYjYwMjJhMzJlMWM2ZTc0MGE1OTI5OTUxZDlkOGNiZWQzYjE2MmIx',
#  'MDY6Q29tbWl0MjMyNTI5ODozNTQwYzMyYTlhZTRjYjIzYWI3MGY3Nzk4ZjQ1YWZmYzAyNzYyZmE3',
#  'MDY6Q29tbWl0MjMyNTI5ODo5MTJiNzQyN2ZjMTM0NjdiYWMwNDJjYzcyZjJlY2NiZGJjMzlkNzcz',
#  'MDY6Q29tbWl0MjMyNTI5ODo1MWZhYzgzODhhMDMyNWE0M2YwYWU2NzQ1M2VjZTJjMzczZTJlYzI4',
#  'C_kwDOACN7MtoAKDZjMGViNWJhMzUwMGY2ZGEzNjczNTFmZjNjNDQ1MmMwMjljYjcyZmE',
#  'MDY6Q29tbWl0MjMyNTI5ODo3ZGFhYTA2MzU3YmY3ZjE4NzRiNjJiYjFlYTlkNjZhNTFkNGU1Njdl',
#  'MDY6Q29tbWl0MjMyNTI5ODplMzQ2ZDBjZjJjMGEyZGM5ZTYzZDViOTA4MjRiYmU1YWMwY2M0M2Uy',
#  'MDY6Q29tbWl0MjMyNTI5ODpkZjMxNmU5MzkxMDBlNzg5YjNjNWQ0ZDEwMjYxOWNjZjU4MzRiZDAw',
#  'MDY6Q29tbWl0MjMyNTI5ODoxMzZhNGRmZTg3Y2QzNGRiMjE1MzMzMGFhODRkYmJjMjEwZWIzNmI2',
#  'MDY6Q29tbWl0MjMyNTI5ODo3Y2RhOTNlMDA4ZTFhNDc3OTcwYWRiZjgyZGJhODFhNWQ0ZjBhZTQw',
#  'MDY6Q29tbWl0MjMyNTI5ODoxYTIwZDQwOWM4NzQyNTUwODZlMmY0MmE3Mjk4MjZkNDkwMjk0Yzkx',
#  'MDY6Q29tbWl0MjMyNTI5ODozZjM5NDJhY2E2ZGEzNTFhMTI1NDNhYTc3NjQ2Nzc5MWI2M2IzYTc4',
#  'MDY6Q29tbWl0MjMyNTI5ODowMGUyNTAzNjdjYzZjNGFiODBmZWE2ZWM2MDVkNDY0ZTYyNGJkNTIw',
#  'MDY6Q29tbWl0MjMyNTI5ODplZTdlMjI2NTNmNTA3NzE2OWVjNzA2YjVhMTQwYTNiZTlkYjM4MWU3',
#  'MDY6Q29tbWl0MjMyNTI5ODoxYmE5MGUzYTg3YzQ2NTAwNjIzYWZkYzM4OTg1NzNlNGE1ZWJiMjFi',
#  'MDY6Q29tbWl0MjMyNTI5ODo5MGVkOWM2MzljMWI1MzU1NmY4N2IxYzUwMzFjN2U0YzU3Mjg1YTky']

# %%
df_button_predicted_sample = df_button_predicted.loc[df_button_predicted['commit ID'].isin(random_commits_button)]
df_button_predicted_sample
# Out:
#                                              commit ID  \
# 12   C_kwDOACN7MtoAKDZjMGViNWJhMzUwMGY2ZGEzNjczNTFm...
# 13   C_kwDOACN7MtoAKDZjMGViNWJhMzUwMGY2ZGEzNjczNTFm...
# 14   C_kwDOACN7MtoAKDZjMGViNWJhMzUwMGY2ZGEzNjczNTFm...
# 15   C_kwDOACN7MtoAKDZjMGViNWJhMzUwMGY2ZGEzNjczNTFm...
# 16   C_kwDOACN7MtoAKDZjMGViNWJhMzUwMGY2ZGEzNjczNTFm...
# ..                                                 ...
# 528  MDY6Q29tbWl0MjMyNTI5ODo3Y2RhOTNlMDA4ZTFhNDc3OT...
# 529  MDY6Q29tbWl0MjMyNTI5ODo3Y2RhOTNlMDA4ZTFhNDc3OT...
# 530  MDY6Q29tbWl0MjMyNTI5ODo3Y2RhOTNlMDA4ZTFhNDc3OT...
# 565  MDY6Q29tbWl0MjMyNTI5ODo0YmU0NGZjZDNiZjY0OGI3OD...
# 566  MDY6Q29tbWl0MjMyNTI5ODo0YmU0NGZjZDNiZjY0OGI3OD...
#
#                                                   text  predicted_decision  \
# 12      ACPI: make remove callback of ACPI driver void                   1
# 13   For bus-based driver, device removal is implem...                   0
# 14   1 device_remove()->\n2   bus->remove()->\n3   ...                   1
# 15   In that case, commit fc7a6209d571\n("bus: Make...                   1
# 16   Now we have the situation that both 1 & 2 of c...                   0
# ..                                                 ...                 ...
# 528  ACPI: delete extra #defines in /drivers/acpi/ ...                   0
# 529                                      Cosmetic only                   1
# 530  Except in a single case, #define ACPI_*_DRIVER...                   0
# 565                      [ACPI] Lindent all ACPI files                   0
# 566                                                NaN                   0
#
#      predicted_rationale
# 12                     0
# 13                     0
# 14                     1
# 15                     0
# 16                     0
# ..                   ...
# 528                    1
# 529                    1
# 530                    1
# 565                    0
# 566                    0
#
# [91 rows x 4 columns]

# %%
set(df_button_predicted_sample['commit ID'].unique()) == set(random_commits_button)
# Out:
# True

# %%
df_button_predicted_sample.to_csv('sample_of_generalization_results_on_the_button.csv', sep=';', index=False)

# %% [markdown]
# ## Alignment of rater (post-validation)

# %%
import pandas as pd

# %%
df_b = pd.read_csv('Rater_1_sample_of_generalization_results_on_the_button.csv' )
df_b = df_b.rename(columns={"Agree decision ? ": "Agree decision R1", "Agree rationale ?": "Agree rationale R1"})

df_mi = pd.read_csv('Rater_2_sample_of_generalization_results_on_the_button.csv' )
df_mi = df_mi.rename(columns={"Agree decision ? ": "Agree decision R2", "Agree rationale ?": "Agree rationale R2"})

df_mo = pd.read_csv('Rater_3_sample_of_generalization_results_on_the_button.csv' )
df_mo = df_mo.rename(columns={"Agree decision ? ": "Agree decision R3", "Agree rationale ?": "Agree rationale R3"})

# %%
df_button_validation = df_b
df_button_validation['Agree decision R2'] = df_mi['Agree decision R2']
df_button_validation['Agree rationale R2'] = df_mi['Agree rationale R2']
df_button_validation['Agree decision R3'] = df_mo['Agree decision R3']
df_button_validation['Agree rationale R3'] = df_mo['Agree rationale R3']
df_button_validation

# %%
df_button_validation[(df_button_validation['Agree decision R1'] == "yes") & (df_button_validation['Agree decision R2']=="yes") & (df_button_validation['Agree decision R3'] == "yes")  ]

# %%
len(df_button_validation[(df_button_validation['Agree decision R1'] == "yes") & (df_button_validation['Agree decision R2']=="yes") & (df_button_validation['Agree decision R3'] == "yes")  ])
# Out:
# 52

# %%
len(df_button_validation[(df_button_validation['Agree rationale R1'] == "yes") & (df_button_validation['Agree rationale R2']=="yes") & (df_button_validation['Agree rationale R3'] == "yes")  ])
# Out:
# 51

# %%
# yes and no, agreement
len(df_button_validation[(df_button_validation['Agree decision R1'] == df_button_validation['Agree decision R2'] ) & (df_button_validation['Agree decision R3'] == df_button_validation['Agree decision R2'] )  ])
# Out:
# 69

# %%
# yes and no, agreement
len(df_button_validation[(df_button_validation['Agree rationale R1'] == df_button_validation['Agree rationale R2'] ) & (df_button_validation['Agree rationale R3'] == df_button_validation['Agree rationale R2'] )  ])
# Out:
# 55

# %% [markdown]
# # Generalization to other projects (What makes a good commit message dataset)

# %% [markdown]
# ## Prepapre the data

# %% [markdown]
#  * It contains meta-information of 1649 labeled commit messages.
#     * label = 0 means a commit message contains "Why and What".
#     * label = 1 means a commit message  contains "Neither Why nor What".
#     * label = 2 means a commit message  contains "No What" :  “No What”(only Why, but no What);
#     * label = 3 means a commit message  contains "No Why". : “No Why” (only What information, but no Why);
#
#     * if_mulit_commit = 1 means a commit is non-atomic.
#     * new_message1 means a message after preprocessing.

# %%
df_commit = pd.read_csv('sampled messages_what_makes_a_good_commit.csv', encoding='latin-1')
df_commit
# Out:
#          id  repo_id  label  \
# 0      3079        2      0
# 1      5904        4      0
# 2      4224        2      0
# 3      5382        3      0
# 4      6983        4      3
# ...     ...      ...    ...
# 1644   3452        2      0
# 1645   3786        2      2
# 1646   3497        2      0
# 1647  13889        5      0
# 1648   2960        2      2
#
#                                                     url if_mulit_commit  \
# 0     https://github.com/apache/dubbo/commit/1b2e6dc...               1
# 1     https://github.com/square/okhttp/commit/2fd0da...
# 2     https://github.com/apache/dubbo/commit/9e9e778...
# 3     https://github.com/square/retrofit/commit/0754...
# 4     https://github.com/square/okhttp/commit/c310d2...
# ...                                                 ...             ...
# 1644  https://github.com/apache/dubbo/commit/789775b...
# 1645  https://github.com/apache/dubbo/commit/84d355f...
# 1646  https://github.com/apache/dubbo/commit/3bdc316...
# 1647  https://github.com/spring-projects/spring-boot...
# 1648  https://github.com/apache/dubbo/commit/055f1cc...
#
#                                                 message  \
# 0     remove some magic value (#4752) <enter>  <ente...
# 1                         Update concurrency.md (#6290)
# 2             Optimize_hessian_desr_performance (#1705)
# 3                              Add @PartMap annotation.
# 4                workaround broken system dns behaviour
# ...                                                 ...
# 1644  Change CopyOnWriteArrayList to regular list in...
# 1645                                  code rule (#3651)
# 1646      replace Random with ThreadLocalRandom (#2433)
# 1647  Update production-ready-features.adoc <enter> ...
# 1648  [Dubbo-4871] fix cache file name issue in wind...
#
#                                            new_message1   authorEmail  \
# 0     remove some magic value ( <pr_link> )  <enter>...  developer128
# 1                  Update concurrency.md ( <pr_link> )   developer129
# 2      Optimize_hessian_desr_performance ( <pr_link> )   developer130
# 3                               Add <iden> annotation.   developer131
# 4     workaround broken system  <file_name>  behaviour   developer132
# ...                                                 ...           ...
# 1644  Change <iden> to regular list in  <file_name> ...  developer335
# 1645                           code rule ( <pr_link> )   developer336
# 1646          replace <iden> with <iden> ( <pr_link> )   developer337
# 1647  Update  <file_name> <enter> Replace line break...  developer338
# 1648  [Dubbo-4871] fix cache file name issue in wind...  developer339
#
#                 commitDate  Unnamed: 9
# 0     2019-08-06T07:23:45Z         NaN
# 1     2020-09-30T16:01:02Z         NaN
# 2     2018-04-26T10:51:02Z         NaN
# 3     2014-05-01T17:16:02Z         NaN
# 4     2017-11-17T11:02:26Z         NaN
# ...                    ...         ...
# 1644  2019-05-15T03:05:48Z         NaN
# 1645  2019-04-12T03:37:03Z         NaN
# 1646  2018-09-05T03:31:52Z         NaN
# 1647  2016-12-08T11:15:43Z         NaN
# 1648  2019-10-11T13:30:51Z         NaN
#
# [1649 rows x 10 columns]

# %%
df_commit['if_mulit_commit'].value_counts()
# Out:
#      1597
# 1      52
# Name: if_mulit_commit, dtype: int64

# %%
df_commit = df_commit.drop(df_commit[df_commit.if_mulit_commit == '1' ].index)
df_commit
# Out:
#          id  repo_id  label  \
# 1      5904        4      0
# 2      4224        2      0
# 3      5382        3      0
# 4      6983        4      3
# 5      3817        2      0
# ...     ...      ...    ...
# 1644   3452        2      0
# 1645   3786        2      2
# 1646   3497        2      0
# 1647  13889        5      0
# 1648   2960        2      2
#
#                                                     url if_mulit_commit  \
# 1     https://github.com/square/okhttp/commit/2fd0da...
# 2     https://github.com/apache/dubbo/commit/9e9e778...
# 3     https://github.com/square/retrofit/commit/0754...
# 4     https://github.com/square/okhttp/commit/c310d2...
# 5     https://github.com/apache/dubbo/commit/7f262f9...
# ...                                                 ...             ...
# 1644  https://github.com/apache/dubbo/commit/789775b...
# 1645  https://github.com/apache/dubbo/commit/84d355f...
# 1646  https://github.com/apache/dubbo/commit/3bdc316...
# 1647  https://github.com/spring-projects/spring-boot...
# 1648  https://github.com/apache/dubbo/commit/055f1cc...
#
#                                                 message  \
# 1                         Update concurrency.md (#6290)
# 2             Optimize_hessian_desr_performance (#1705)
# 3                              Add @PartMap annotation.
# 4                workaround broken system dns behaviour
# 5                   simplify map empty judgment (#3376)
# ...                                                 ...
# 1644  Change CopyOnWriteArrayList to regular list in...
# 1645                                  code rule (#3651)
# 1646      replace Random with ThreadLocalRandom (#2433)
# 1647  Update production-ready-features.adoc <enter> ...
# 1648  [Dubbo-4871] fix cache file name issue in wind...
#
#                                            new_message1   authorEmail  \
# 1                  Update concurrency.md ( <pr_link> )   developer129
# 2      Optimize_hessian_desr_performance ( <pr_link> )   developer130
# 3                               Add <iden> annotation.   developer131
# 4     workaround broken system  <file_name>  behaviour   developer132
# 5            simplify map empty judgment ( <pr_link> )   developer133
# ...                                                 ...           ...
# 1644  Change <iden> to regular list in  <file_name> ...  developer335
# 1645                           code rule ( <pr_link> )   developer336
# 1646          replace <iden> with <iden> ( <pr_link> )   developer337
# 1647  Update  <file_name> <enter> Replace line break...  developer338
# 1648  [Dubbo-4871] fix cache file name issue in wind...  developer339
#
#                 commitDate  Unnamed: 9
# 1     2020-09-30T16:01:02Z         NaN
# 2     2018-04-26T10:51:02Z         NaN
# 3     2014-05-01T17:16:02Z         NaN
# 4     2017-11-17T11:02:26Z         NaN
# 5     2019-01-29T05:38:51Z         NaN
# ...                    ...         ...
# 1644  2019-05-15T03:05:48Z         NaN
# 1645  2019-04-12T03:37:03Z         NaN
# 1646  2018-09-05T03:31:52Z         NaN
# 1647  2016-12-08T11:15:43Z         NaN
# 1648  2019-10-11T13:30:51Z         NaN
#
# [1597 rows x 10 columns]

# %%
df_commit = df_commit.drop(columns=['authorEmail', 'commitDate', 'message', 'id','Unnamed: 9', 'if_mulit_commit'])
df_commit
# Out:
#       repo_id  label                                                url  \
# 1           4      0  https://github.com/square/okhttp/commit/2fd0da...
# 2           2      0  https://github.com/apache/dubbo/commit/9e9e778...
# 3           3      0  https://github.com/square/retrofit/commit/0754...
# 4           4      3  https://github.com/square/okhttp/commit/c310d2...
# 5           2      0  https://github.com/apache/dubbo/commit/7f262f9...
# ...       ...    ...                                                ...
# 1644        2      0  https://github.com/apache/dubbo/commit/789775b...
# 1645        2      2  https://github.com/apache/dubbo/commit/84d355f...
# 1646        2      0  https://github.com/apache/dubbo/commit/3bdc316...
# 1647        5      0  https://github.com/spring-projects/spring-boot...
# 1648        2      2  https://github.com/apache/dubbo/commit/055f1cc...
#
#                                            new_message1
# 1                  Update concurrency.md ( <pr_link> )
# 2      Optimize_hessian_desr_performance ( <pr_link> )
# 3                               Add <iden> annotation.
# 4     workaround broken system  <file_name>  behaviour
# 5            simplify map empty judgment ( <pr_link> )
# ...                                                 ...
# 1644  Change <iden> to regular list in  <file_name> ...
# 1645                           code rule ( <pr_link> )
# 1646          replace <iden> with <iden> ( <pr_link> )
# 1647  Update  <file_name> <enter> Replace line break...
# 1648  [Dubbo-4871] fix cache file name issue in wind...
#
# [1597 rows x 4 columns]

# %%
df_commit['Decision']=df_commit['label'].apply(lambda x: 1 if (x==0 or x == 3) else 0)  # both + no why
df_commit['Rationale']=df_commit['label'].apply(lambda x: 1 if (x==0 or x == 2) else 0)  # both + no what
df_commit
# Out:
#       repo_id  label                                                url  \
# 1           4      0  https://github.com/square/okhttp/commit/2fd0da...
# 2           2      0  https://github.com/apache/dubbo/commit/9e9e778...
# 3           3      0  https://github.com/square/retrofit/commit/0754...
# 4           4      3  https://github.com/square/okhttp/commit/c310d2...
# 5           2      0  https://github.com/apache/dubbo/commit/7f262f9...
# ...       ...    ...                                                ...
# 1644        2      0  https://github.com/apache/dubbo/commit/789775b...
# 1645        2      2  https://github.com/apache/dubbo/commit/84d355f...
# 1646        2      0  https://github.com/apache/dubbo/commit/3bdc316...
# 1647        5      0  https://github.com/spring-projects/spring-boot...
# 1648        2      2  https://github.com/apache/dubbo/commit/055f1cc...
#
#                                            new_message1  Decision  Rationale
# 1                  Update concurrency.md ( <pr_link> )          1          1
# 2      Optimize_hessian_desr_performance ( <pr_link> )          1          1
# 3                               Add <iden> annotation.          1          1
# 4     workaround broken system  <file_name>  behaviour          1          0
# 5            simplify map empty judgment ( <pr_link> )          1          1
# ...                                                 ...       ...        ...
# 1644  Change <iden> to regular list in  <file_name> ...         1          1
# 1645                           code rule ( <pr_link> )          0          1
# 1646          replace <iden> with <iden> ( <pr_link> )          1          1
# 1647  Update  <file_name> <enter> Replace line break...         1          1
# 1648  [Dubbo-4871] fix cache file name issue in wind...         0          1
#
# [1597 rows x 6 columns]

# %% [markdown]
# Note: These are at the commit level!

# %% [markdown]
# ## Test the classifiers

# %%
X_test =  df_commit['new_message1']

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(X_test.astype(str))
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)


# Making Decision predictions
y_pred_prob = model_decision.predict(padded_sequences) ## change here !!!!!
y_pred = (y_pred_prob > 0.5).astype(int)  # Threshold probabilities to get binary predictions
y_pred = y_pred.flatten()

df_commit['predicted_decision'] = y_pred


# Making Rationale predictions
y_pred_prob = model_rationale.predict(padded_sequences) ## change here !!!!!
y_pred = (y_pred_prob > 0.5).astype(int)  # Threshold probabilities to get binary predictions
y_pred = y_pred.flatten()

df_commit['predicted_rationale'] = y_pred


df_commit
# Out:
# 50/50 [==============================] - 2s 32ms/step
# 50/50 [==============================] - 2s 31ms/step
#       repo_id  label                                                url  \
# 1           4      0  https://github.com/square/okhttp/commit/2fd0da...
# 2           2      0  https://github.com/apache/dubbo/commit/9e9e778...
# 3           3      0  https://github.com/square/retrofit/commit/0754...
# 4           4      3  https://github.com/square/okhttp/commit/c310d2...
# 5           2      0  https://github.com/apache/dubbo/commit/7f262f9...
# ...       ...    ...                                                ...
# 1644        2      0  https://github.com/apache/dubbo/commit/789775b...
# 1645        2      2  https://github.com/apache/dubbo/commit/84d355f...
# 1646        2      0  https://github.com/apache/dubbo/commit/3bdc316...
# 1647        5      0  https://github.com/spring-projects/spring-boot...
# 1648        2      2  https://github.com/apache/dubbo/commit/055f1cc...
#
#                                            new_message1  Decision  Rationale  \
# 1                  Update concurrency.md ( <pr_link> )          1          1
# 2      Optimize_hessian_desr_performance ( <pr_link> )          1          1
# 3                               Add <iden> annotation.          1          1
# 4     workaround broken system  <file_name>  behaviour          1          0
# 5            simplify map empty judgment ( <pr_link> )          1          1
# ...                                                 ...       ...        ...
# 1644  Change <iden> to regular list in  <file_name> ...         1          1
# 1645                           code rule ( <pr_link> )          0          1
# 1646          replace <iden> with <iden> ( <pr_link> )          1          1
# 1647  Update  <file_name> <enter> Replace line break...         1          1
# 1648  [Dubbo-4871] fix cache file name issue in wind...         0          1
#
#       predicted_decision  predicted_rationale
# 1                      1                    1
# 2                      1                    0
# 3                      1                    1
# 4                      1                    1
# 5                      1                    1
# ...                  ...                  ...
# 1644                   1                    1
# 1645                   1                    0
# 1646                   1                    0
# 1647                   1                    1
# 1648                   1                    1
#
# [1597 rows x 8 columns]

# %%
df_commit.to_csv('generalization_results_on_the_commit_messages_paper.csv', sep=';', index=False)

# %%
import pandas as pd
df_commit = pd.read_csv('generalization_results_on_the_commit_messages_paper.csv' , sep=';', encoding ='latin-1')
df_commit
# Out:
#       repo_id  label                                                url  \
# 0           4      0  https://github.com/square/okhttp/commit/2fd0da...
# 1           2      0  https://github.com/apache/dubbo/commit/9e9e778...
# 2           3      0  https://github.com/square/retrofit/commit/0754...
# 3           4      3  https://github.com/square/okhttp/commit/c310d2...
# 4           2      0  https://github.com/apache/dubbo/commit/7f262f9...
# ...       ...    ...                                                ...
# 1592        2      0  https://github.com/apache/dubbo/commit/789775b...
# 1593        2      2  https://github.com/apache/dubbo/commit/84d355f...
# 1594        2      0  https://github.com/apache/dubbo/commit/3bdc316...
# 1595        5      0  https://github.com/spring-projects/spring-boot...
# 1596        2      2  https://github.com/apache/dubbo/commit/055f1cc...
#
#                                            new_message1  Decision  Rationale  \
# 0                  Update concurrency.md ( <pr_link> )          1          1
# 1      Optimize_hessian_desr_performance ( <pr_link> )          1          1
# 2                               Add <iden> annotation.          1          1
# 3     workaround broken system  <file_name>  behaviour          1          0
# 4            simplify map empty judgment ( <pr_link> )          1          1
# ...                                                 ...       ...        ...
# 1592  Change <iden> to regular list in  <file_name> ...         1          1
# 1593                           code rule ( <pr_link> )          0          1
# 1594          replace <iden> with <iden> ( <pr_link> )          1          1
# 1595  Update  <file_name> <enter> Replace line break...         1          1
# 1596  [Dubbo-4871] fix cache file name issue in wind...         0          1
#
#       predicted_decision  predicted_rationale
# 0                      1                    1
# 1                      1                    0
# 2                      1                    1
# 3                      1                    1
# 4                      1                    1
# ...                  ...                  ...
# 1592                   1                    1
# 1593                   1                    0
# 1594                   1                    0
# 1595                   1                    1
# 1596                   1                    1
#
# [1597 rows x 8 columns]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


accuracy = accuracy_score(df_commit['Decision'], df_commit['predicted_decision'])
precision = precision_score(df_commit['Decision'], df_commit['predicted_decision'])
recall = recall_score(df_commit['Decision'], df_commit['predicted_decision'])
f1 = f1_score(df_commit['Decision'], df_commit['predicted_decision'])

print("Test Metrics Decision:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")

#############
accuracy = accuracy_score(df_commit['Rationale'], df_commit['predicted_rationale'])
precision = precision_score(df_commit['Rationale'], df_commit['predicted_rationale'])
recall = recall_score(df_commit['Rationale'], df_commit['predicted_rationale'])
f1 = f1_score(df_commit['Rationale'], df_commit['predicted_rationale'])

print("\n Test Metrics Rationale:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Test Metrics Decision:
# Accuracy: 0.5616781465247339
# Precision: 0.8280773143438453
# Recall: 0.6052044609665428
# F1 Score: 0.6993127147766323
#
#  Test Metrics Rationale:
# Accuracy: 0.6393237319974953
# Precision: 0.7272727272727273
# Recall: 0.7667269439421338
# F1 Score: 0.7464788732394367
